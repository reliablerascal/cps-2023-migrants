# %% [markdown]
# # 1. Read Data

# %%
import pandas as pd

# %%
df_schools = pd.read_csv("../results/cps_school_sy2223_sy2324.csv",index_col=[0])
df_schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 645 entries, 0 to 644
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   school_id               645 non-null    int64
#  1   short_name              645 non-null    object
#  2   long_name               645 non-null    object
#  3   primary_category        645 non-null    object
#  4   is_high_school          645 non-null    bool
#  5   is_middle_school        645 non-null    bool
#  6   is_elementary_school    645 non-null    bool
#  7   is_pre_school           645 non-null    bool
#  8   school_latitude         645 non-null    float64
#  9   school_longitude        645 non-null    float64
#  10  n_y1                    645 non-null    int64
#  11  n_low_income_y1         645 non-null    int64
#  12  n_special_y1            645 non-null    int64
#  13  n_english_learn_y1      645 non-null    int64
# ...

# %%
df_communities = pd.read_csv("../results/cps_community_sy2223_sy2324.csv",index_col=[0])
df_communities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 0 to 76
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   community_name          77 non-null     object
#  1   n_y1                    77 non-null     int64
#  2   n_y2                    77 non-null     int64
#  3   n_english_learn_y1      77 non-null     int64
#  4   n_english_learn_y2      77 non-null     int64
#  5   n_non_english_learn_y1  77 non-null     int64
#  6   n_non_english_learn_y2  77 non-null     int64
#  7   n_low_income_y1         77 non-null     int64
#  8   n_low_income_y2         77 non-null     int64
#  9   n_hispanic_y1           77 non-null     int64
#  10  n_hispanic_y2           77 non-null     int64
#  11  n_schools               77 non-null     int64
#  12  d_total                 77 non-null     int64
#  13  d_low_income            77 non-null     int64
# ...

# %%
df_total = pd.read_csv("../results/cps_total_sy2223_sy2324.csv",index_col=[0])
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 0 to 0
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   n_y1                    1 non-null      int64
#  1   n_y2                    1 non-null      int64
#  2   n_english_learn_y1      1 non-null      int64
#  3   n_english_learn_y2      1 non-null      int64
#  4   n_non_english_learn_y1  1 non-null      int64
#  5   n_non_english_learn_y2  1 non-null      int64
#  6   n_low_income_y1         1 non-null      int64
#  7   n_low_income_y2         1 non-null      int64
#  8   n_hispanic_y1           1 non-null      int64
#  9   n_hispanic_y2           1 non-null      int64
#  10  d_total                 1 non-null      int64
#  11  d_low_income            1 non-null      int64
#  12  d_english_learn         1 non-null      int64
#  13  d_non_english_learn     1 non-null      int64
# ...

# %% [markdown]
# # 1. Overall Summary

# %%
df_total
# Out:
#      n_y1    n_y2  n_english_learn_y1  n_english_learn_y2  \
# 0  321432  320612               71744               75367
#
#    n_non_english_learn_y1  n_non_english_learn_y2  n_low_income_y1  \
# 0                  249688                  245245           220511
#
#    n_low_income_y2  n_hispanic_y1  n_hispanic_y2  d_total  d_low_income  \
# 0           215184         149560         150412     -820         -5327
#
#    d_english_learn  d_non_english_learn  d_hispanic  pct_total  \
# 0             3623                -4443         852  -0.255108
#
#    pct_low_income  pct_english_learn  pct_non_english_learn  pct_hispanic
# 0       -2.415753             5.0499              -1.779421      0.569671

# %% [markdown]
# # 2. Community Area Summaries

# %% [markdown]
# ### top 10 increased enrollment overall

# %%
df_communities.sort_values(by='d_total',ascending=False)[['community_name','n_schools','d_total','d_english_learn','d_non_english_learn']].head(10)
# Out:
#      community_name  n_schools  d_total  d_english_learn  d_non_english_learn
# 75        WEST TOWN         24      416              520                 -104
# 45      MORGAN PARK          7      263               -2                  265
# 60      ROGERS PARK          7      242              102                  140
# 57     PORTAGE PARK          8      199              103                   96
# 39   LINCOLN SQUARE          6      193               82                  111
# 0       ALBANY PARK          9      179              225                  -46
# 37        LAKE VIEW         10      178              161                   17
# 41             LOOP          3      144               39                  105
# 24      FOREST GLEN          3      136                0                  136
# 47  NEAR NORTH SIDE          7      126               97                   29

# %% [markdown]
# ### top 10 increased english learners

# %%
df_communities_english_10 = df_communities.sort_values(by='d_english_learn',ascending=False)[['community_name','n_schools','d_english_learn','d_total','n_english_learn_y1','n_english_learn_y2','n_y1','n_y2']].head(10)
df_communities_english_10
# Out:
#    community_name  n_schools  d_english_learn  d_total  n_english_learn_y1  \
# 75      WEST TOWN         24              520      416                2329
# 32  HUMBOLDT PARK         17              256       77                2071
# 0     ALBANY PARK          9              225      179                2921
# 54   NORWOOD PARK          8              208      -67                1221
# 74     WEST RIDGE         10              188       94                3433
# 37      LAKE VIEW         10              161      178                 832
# 31        HERMOSA          5              148       82                1342
# 5          AUSTIN         23              146     -117                 452
# 21      EDGEWATER          5              145       42                1395
# 53     NORTH PARK          6              115       42                 972
#
#     n_english_learn_y2   n_y1   n_y2
# 75                2849  10312  10728
# 32                2327   8216   8293
# ...

# %% [markdown]
# # 3. School Summaries

# %% [markdown]
# ### top 10 increased enrollment overall

# %%
df_schools.sort_values(by='d_total',ascending=False)[['short_name','community_name','d_total','d_english_learn','d_non_english_learn','n_y1','n_y2']].head(10)
# Out:
#                        short_name community_name  d_total  d_english_learn  \
# 296  PERSPECTIVES - LEADERSHIP HS        CHATHAM      191                1
# 137                   CLEMENTE HS      WEST TOWN      149              180
# 85              NOBLE - MUCHIN HS           LOOP      138               25
# 59                        KING HS        KENWOOD      116                0
# 540                       GREELEY      LAKE VIEW      114              103
# 283                  HYDE PARK HS       WOODLAWN      108                3
# 581                      DE DIEGO      WEST TOWN      101               52
# 434                       DIRKSEN          OHARE      100               23
# 438                     SOR JUANA    WEST ELSDON       92                1
# 161                           RAY      HYDE PARK       91               -5
#
#      d_non_english_learn  n_y1  n_y2
# 296                  190   643   834
# 137                  -31   595   744
# ...

# %% [markdown]
# ### top 10 increased english learners

# %%
df_schools_english_10 = df_schools.sort_values(by='d_english_learn',ascending=False)[['short_name','community_name','d_english_learn','d_non_english_learn','d_total','n_english_learn_y1','n_english_learn_y2','n_non_english_learn_y1','n_non_english_learn_y2','n_y1','n_y2']].head(10)
df_schools_english_10
# Out:
#               short_name   community_name  d_english_learn  \
# 144              TAFT HS     NORWOOD PARK              185
# 137          CLEMENTE HS        WEST TOWN              180
# 236             CURIE HS   ARCHER HEIGHTS              133
# 619            MATHER HS       WEST RIDGE              115
# 540              GREELEY        LAKE VIEW              103
# 472         ROOSEVELT HS      ALBANY PARK               89
# 213               LOZANO        WEST TOWN               86
# 468  NOBLE - PRITZKER HS          HERMOSA               84
# 225              CAMERON    HUMBOLDT PARK               83
# 149            JUAREZ HS  LOWER WEST SIDE               81
#
#      d_non_english_learn  d_total  n_english_learn_y1  n_english_learn_y2  \
# 144                 -263      -78                 601                 786
# 137                  -31      149                 120                 300
# 236                 -127        6                 666                 799
# ...

# %% [markdown]
# # 4. Export for Graphics

# %%
df_communities_english_10.to_csv("../results/cps_el_top10_comm.csv")
df_schools_english_10.to_csv("../results/cps_el_top10_schools.csv")
